# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from netCDF4 import Dataset
import xarray as xr
import glob
import os
import py7zr

# %% [markdown]
# ## Build list of COMIDs (by HUC10) from retrospective datasets (temp and covariates)

# %%
temp_dir = '/Volumes/Elements/URycki/temp_data/'

# %%
# Loop through HUC 10s
retro_comids = []
temp_dir_retro = os.path.join(temp_dir, 'preds_retro/')
huc10_retro_files = glob.glob(os.path.join(temp_dir_retro, 'temp_files', '*/*.csv'))
huc10_retro_files.sort()
len(huc10_retro_files)
# Out:
# 1541

# %%
# Caution: This cell takes ~3 hours to run
# Temp files
retro_comids = {}
for h in huc10_retro_files:
    cur_huc = h[-14:-4] 
    print('\t', f'{cur_huc}')

    stdf = pd.read_csv(h, usecols = ['COMID'])
    retro_comids[cur_huc] = stdf.COMID.unique().tolist()
# Out:
# 	 1701010106

# %%
#Make dataframe with COMID as index [from retrospective temp predictions dataset]
frames = []
for k in retro_comids.keys():
    curdf = pd.DataFrame(retro_comids[k], columns = ['COMID'])
    curdf['huc10'] = k
    frames.append(curdf)
comids = pd.concat(frames).set_index('COMID')
comids.to_csv(os.path.join(temp_dir_retro, 'comids_by_huc_retro.csv'))

# %%
cov_csvs = glob.glob(os.path.join(temp_dir, 'covariates_retro', 'cov_csvs', '*'))
cov_csvs.sort()

# %%
# %%time
# Covariate files
retro_cov_comids = {}
for h in cov_csvs:
    cur_huc = h[-19:-9]
    print('\t', f'{cur_huc}')

    stdf = pd.read_csv(h, usecols = ['COMID'])
    retro_cov_comids[cur_huc] = stdf.COMID.unique().tolist()

# %%
frames = []
for k in retro_cov_comids.keys():
    curdf = pd.DataFrame(retro_cov_comids[k], columns = ['COMID'])
    curdf['huc10'] = k
    frames.append(curdf)
comids = pd.concat(frames).set_index('COMID')
comids.to_csv(os.path.join(temp_dir_retro, 'comids_by_huc_cov_retro.csv'))

# %% [markdown]
# ### Import lists of COMIDs

# %%
comids_temp = pd.read_csv(os.path.join(temp_dir_retro, 'comids_by_huc_retro.csv'))
comids_cov = pd.read_csv(os.path.join(temp_dir_retro, 'comids_by_huc_cov_retro.csv'))

comids_all = pd.concat([comids_temp.set_index('COMID'), comids_cov.set_index('COMID')])
#df3[~df3.index.duplicated(keep='first')]
comids_all = comids_all[~comids_all.index.duplicated(keep = 'first')]
comids_all.sort_index(inplace = True)

comids_all

# %% [markdown]
# ## Layer 1: ComID geometry table
# ### Import flowlines

# %%
dbfhydro_files = glob.glob(r'../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/*/*.dbf') 
dbfhydro_files
# Out:
# ['../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDFlowline.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDLineEventFC.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDArea.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDPoint.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDAreaEventFC.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDPointEventFC.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDLine.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDSnapshot/Hydrography/NHDWaterbody.dbf']

# %%
flowlines = gpd.read_file(dbfhydro_files[0])
flowlines[:3]
# Out:
# /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pyogrio/raw.py:198: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D LineString' is converted to 'LineString Z'
#   return ogr_read(
#       COMID      FDATE RESOLUTION GNIS_ID GNIS_NAME  LENGTHKM       REACHCODE  \
# 0   9301535 1999-10-08     Medium    None      None     0.999  09040002011583
# 1  22968128 2001-03-02     Medium    None      None     0.134  10030104009812
# 2  22968138 2001-03-02     Medium    None      None     0.217  10030104009813
#
#          FLOWDIR  WBAREACOMI        FTYPE  FCODE  SHAPE_LENG ENABLED  \
# 0  Uninitialized           0  StreamRiver  46006    0.011661    True
# 1  Uninitialized           0  StreamRiver  46003    0.001671    True
# 2  Uninitialized           0  StreamRiver  46003    0.002145    True
#
#    GNIS_NBR                                           geometry
# 0         0  LINESTRING Z (-114.05855 48.99999 0, -114.0583...
# 1         0  LINESTRING Z (-113.00089 47.46274 0, -113.0020...
# 2         0  LINESTRING Z (-113.0013 47.45837 0, -113.00137...

# %%
flowlines.columns
# Out:
# Index(['COMID', 'FDATE', 'RESOLUTION', 'GNIS_ID', 'GNIS_NAME', 'LENGTHKM',
#        'REACHCODE', 'FLOWDIR', 'WBAREACOMI', 'FTYPE', 'FCODE', 'SHAPE_LENG',
#        'ENABLED', 'GNIS_NBR', 'geometry'],
#       dtype='object')

# %%
comids_all
# Out:
#                  huc10
# COMID
# -81754      1712000410
# -81753      1712000810
# -81752      1712000907
# -81751      1704021405
# -81750      1704021506
# ...                ...
#  947120094  1712000603
#  947120095  1712000603
#  947120098  1712000603
#  947120100  1712000603
#  947120101  1712000603
#
# [228673 rows x 1 columns]

# %%
# concat Fcode and geometry from flowlines df
df_geom = pd.concat([comids_all, flowlines[['COMID', 'FCODE', 'geometry']].set_index('COMID')], axis = 1, join = 'inner')
df_geom
# Out:
#                 huc10  FCODE  \
# COMID
# 22877591   1701010117  55800
# 22877593   1701010117  55800
# 22877595   1701010117  46006
# 22877597   1701010117  46006
# 22877599   1701010117  46006
# ...               ...    ...
# 947120094  1712000603  46006
# 947120095  1712000603  46006
# 947120098  1712000603  46006
# 947120100  1712000603  46003
# 947120101  1712000603  46003
#
#                                                     geometry
# COMID
# 22877591   LINESTRING Z (-115.97665 48.55862 0, -115.9780...
# 22877593   LINESTRING Z (-115.97724 48.55831 0, -115.9766...
# 22877595   LINESTRING Z (-116.00101 48.55763 0, -116.0006...
# 22877597   LINESTRING Z (-116.01247 48.55595 0, -116.0086...
# 22877599   LINESTRING Z (-116.02837 48.55589 0, -116.0243...
# ...                                                      ...
# 947120094  LINESTRING Z (-120.32129 42.38282 0, -120.3207...
# 947120095  LINESTRING Z (-120.31769 42.38113 0, -120.3175...
# 947120098  LINESTRING Z (-120.33013 42.3911 0, -120.32983...
# 947120100  LINESTRING Z (-120.30641 42.35695 0, -120.3063...
# 947120101  LINESTRING Z (-120.31349 42.3795 0, -120.31348...
#
# [227994 rows x 3 columns]

# %%
# concat spatial covariates
spatial_covs = pd.read_csv(r'../DATA/Stream_Temp/spatial_data.csv', index_col = 'COMID')
spatial_covs.rename(columns = {'cov.extru_vol_cat': 'cov.pct_extru_vol_cat'}, inplace = True)
spatial_covs
# Out:
#            cov.length_km  cov.stream_order  cov.path_length  cov.tot.da.sqkm  \
# COMID
# 9301535            0.999               NaN              NaN              NaN
# 22226592           0.733               NaN              NaN              NaN
# 22226600           6.117               NaN              NaN              NaN
# 22877591           0.247               6.0         1290.195       28030.5369
# 22877593           0.055               3.0         1290.442          58.4136
# ...                  ...               ...              ...              ...
# 947120097          0.161               NaN              NaN              NaN
# 947120098          1.218               2.0           40.722          10.9971
# 947120099          0.366               NaN              NaN              NaN
# 947120100          2.893               3.0           39.940          44.0622
# 947120101          0.445               3.0           39.495          55.6632
#
#            cov.elev_max_smo  cov.elev_min_smo  cov.slope  cov.sinuosity  \
# COMID
# 9301535                 NaN               NaN        NaN           1.47
# 22226592                NaN               NaN        NaN           1.13
# 22226600                NaN               NaN        NaN           1.62
# 22877591            56102.0           55932.0   0.006883           1.00
# 22877593            56129.0           56102.0   0.004909           1.00
# ...                     ...               ...        ...            ...
# 947120097               NaN               NaN        NaN           1.00
# 947120098          145858.0          139672.0   0.050788           1.04
# 947120099               NaN               NaN        NaN           1.01
# 947120100          140135.0          138629.0   0.005206           1.12
# 947120101          138629.0          138331.0   0.006697           1.04
#
#            cov.lat_v  cov.elev_mean_smo  ...  cov.pct_urb_all_ws  \
# COMID                                    ...
# 9301535          NaN                NaN  ...                 NaN
# 22226592         NaN                NaN  ...                 NaN
# 22226600         NaN                NaN  ...                 NaN
# 22877591   48.558399            560.170  ...            0.946698
# 22877593   48.556999            561.155  ...            0.000000
# ...              ...                ...  ...                 ...
# 947120097        NaN                NaN  ...                 NaN
# 947120098  42.388000           1427.650  ...            0.000000
# 947120099        NaN                NaN  ...                 NaN
# 947120100  42.368198           1393.820  ...            0.449365
# 947120101  42.383201           1384.800  ...            0.355711
#
#            cov.canopy_rca  cov.canopy_line  cov.area_sqkm  cov.canopy_ws  \
# COMID
# 9301535               NaN              NaN            NaN            NaN
# 22226592              NaN              NaN            NaN            NaN
# 22226600              NaN              NaN            NaN            NaN
# 22877591        89.000000             90.0         1.9161      88.592748
# 22877593        90.000000             90.0         0.4284      90.227047
# ...                   ...              ...            ...            ...
# 947120097             NaN              NaN            NaN            NaN
# 947120098       82.333333             82.0         0.4815      82.684671
# 947120099             NaN              NaN            NaN            NaN
# 947120100       81.000000             78.0         0.2196      80.865589
# 947120101       81.500000             80.0         1.4031      81.230965
#
#            cov.dam_name  cov.proportion_dam_influenced  \
# COMID
# 9301535             NaN                            NaN
# 22226592            NaN                            NaN
# 22226600            NaN                            NaN
# 22877591          Libby                       0.831332
# 22877593            NaN                            NaN
# ...                 ...                            ...
# 947120097           NaN                            NaN
# 947120098           NaN                            NaN
# 947120099           NaN                            NaN
# 947120100           NaN                            NaN
# 947120101           NaN                            NaN
#
#            cov.distance_below_dam  cov.dam_hgt_m  cov.dam_main_use
# COMID
# 9301535                       NaN            NaN               NaN
# 22226592                      NaN            NaN               NaN
# 22226600                      NaN            NaN               NaN
# 22877591                   71.294          129.0  Hydroelectricity
# 22877593                      NaN            NaN               NaN
# ...                           ...            ...               ...
# 947120097                     NaN            NaN               NaN
# 947120098                     NaN            NaN               NaN
# 947120099                     NaN            NaN               NaN
# 947120100                     NaN            NaN               NaN
# 947120101                     NaN            NaN               NaN
#
# [270941 rows x 76 columns]

# %%
spatial_covs.loc[~spatial_covs.index.isin(df_geom.index)]
# Out:
#            cov.length_km  cov.stream_order  cov.path_length  cov.tot.da.sqkm  \
# COMID
# 9301535            0.999               NaN              NaN              NaN
# 22226592           0.733               NaN              NaN              NaN
# 22226600           6.117               NaN              NaN              NaN
# 22877719           0.036               3.0         1306.120         125.0667
# 22877871           0.024               2.0         1314.134           2.0835
# ...                  ...               ...              ...              ...
# 947120083          0.058               3.0            7.035        1785.2382
# 947120092          0.869               6.0            0.000        3182.1678
# 947120096          0.626               NaN              NaN              NaN
# 947120097          0.161               NaN              NaN              NaN
# 947120099          0.366               NaN              NaN              NaN
#
#            cov.elev_max_smo  cov.elev_min_smo  cov.slope  cov.sinuosity  \
# COMID
# 9301535                 NaN               NaN        NaN           1.47
# 22226592                NaN               NaN        NaN           1.13
# 22226600                NaN               NaN        NaN           1.62
# 22877719            57383.0           57383.0    0.00001           1.00
# 22877871            58878.0           58695.0    0.07625           1.00
# ...                     ...               ...        ...            ...
# 947120083          124996.0          124996.0    0.00001           1.00
# 947120092          124996.0          124996.0    0.00001           1.00
# 947120096               NaN               NaN        NaN           1.09
# 947120097               NaN               NaN        NaN           1.00
# 947120099               NaN               NaN        NaN           1.01
#
#            cov.lat_v  cov.elev_mean_smo  ...  cov.pct_urb_all_ws  \
# COMID                                    ...
# 9301535          NaN                NaN  ...                 NaN
# 22226592         NaN                NaN  ...                 NaN
# 22226600         NaN                NaN  ...                 NaN
# 22877719         NaN            573.830  ...                 NaN
# 22877871         NaN            587.865  ...                 NaN
# ...              ...                ...  ...                 ...
# 947120083  43.350601           1249.960  ...            2.423727
# 947120092  43.354499           1249.960  ...            1.356886
# 947120096        NaN                NaN  ...                 NaN
# 947120097        NaN                NaN  ...                 NaN
# 947120099        NaN                NaN  ...                 NaN
#
#            cov.canopy_rca  cov.canopy_line  cov.area_sqkm  cov.canopy_ws  \
# COMID
# 9301535               NaN              NaN            NaN            NaN
# 22226592              NaN              NaN            NaN            NaN
# 22226600              NaN              NaN            NaN            NaN
# 22877719              NaN              NaN            NaN            NaN
# 22877871              NaN              NaN            NaN            NaN
# ...                   ...              ...            ...            ...
# 947120083             0.0              0.0        57.8727      18.626561
# 947120092             7.5              7.5         0.0333      48.597820
# 947120096             NaN              NaN            NaN            NaN
# 947120097             NaN              NaN            NaN            NaN
# 947120099             NaN              NaN            NaN            NaN
#
#            cov.dam_name  cov.proportion_dam_influenced  \
# COMID
# 9301535             NaN                            NaN
# 22226592            NaN                            NaN
# 22226600            NaN                            NaN
# 22877719            NaN                            NaN
# 22877871            NaN                            NaN
# ...                 ...                            ...
# 947120083           NaN                            NaN
# 947120092           NaN                            NaN
# 947120096           NaN                            NaN
# 947120097           NaN                            NaN
# 947120099           NaN                            NaN
#
#            cov.distance_below_dam  cov.dam_hgt_m  cov.dam_main_use
# COMID
# 9301535                       NaN            NaN               NaN
# 22226592                      NaN            NaN               NaN
# 22226600                      NaN            NaN               NaN
# 22877719                      NaN            NaN               NaN
# 22877871                      NaN            NaN               NaN
# ...                           ...            ...               ...
# 947120083                     NaN            NaN               NaN
# 947120092                     NaN            NaN               NaN
# 947120096                     NaN            NaN               NaN
# 947120097                     NaN            NaN               NaN
# 947120099                     NaN            NaN               NaN
#
# [43881 rows x 76 columns]

# %%
df_all = pd.concat([df_geom, spatial_covs], axis = 1, join = 'inner')

# %%
spatial_gpd = gpd.GeoDataFrame(df_all)
spatial_gpd.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
#spatial_gpd[:25].explore()

# %% [markdown]
# ### Import subcatchments (aka "wings")

# %%
subcatchment_files = glob.glob(r'../DATA/NHDPlusPN/NHDPlus17/NHDPlusCatchment/*.dbf') 
subcatchment_files
# Out:
# ['../DATA/NHDPlusPN/NHDPlus17/NHDPlusCatchment/Catchment.dbf',
#  '../DATA/NHDPlusPN/NHDPlus17/NHDPlusCatchment/featureidgridcode.dbf']

# %%
subcs = gpd.read_file(subcatchment_files[0])
subcs[:3]
# Out:
#    GRIDCODE  FEATUREID     SOURCEFC  AreaSqKM  \
# 0    287844   24324012  NHDFlowline    1.7658
# 1    287845   24324160  NHDFlowline    2.9475
# 2    287846   24324144  NHDFlowline    4.9176
#
#                                             geometry
# 0  POLYGON ((-114.02984 45.94511, -114.03022 45.9...
# 1  POLYGON ((-113.77339 45.90888, -113.77354 45.9...
# 2  POLYGON ((-113.9427 45.90121, -113.94291 45.90...

# %%
subcs['catchment_ID'] = subcs['FEATUREID']
subcs
# Out:
#         GRIDCODE  FEATUREID     SOURCEFC  AreaSqKM  \
# 0         287844   24324012  NHDFlowline    1.7658
# 1         287845   24324160  NHDFlowline    2.9475
# 2         287846   24324144  NHDFlowline    4.9176
# 3         287847   24324280  NHDFlowline    0.0423
# 4         287848   24324608  NHDFlowline    2.5938
# ...          ...        ...          ...       ...
# 231693    522958   23989721  NHDFlowline    9.3834
# 231694    522959   23989715  NHDFlowline   16.4007
# 231695    522960   23989745  NHDFlowline    0.4815
# 231696    522961   24255303  NHDFlowline    0.2196
# 231697    522962   23021612  NHDFlowline    1.4031
#
#                                                  geometry  catchment_ID
# 0       POLYGON ((-114.02984 45.94511, -114.03022 45.9...      24324012
# 1       POLYGON ((-113.77339 45.90888, -113.77354 45.9...      24324160
# 2       POLYGON ((-113.9427 45.90121, -113.94291 45.90...      24324144
# 3       POLYGON ((-114.21125 45.86419, -114.21132 45.8...      24324280
# 4       POLYGON ((-114.09189 45.74334, -114.09226 45.7...      24324608
# ...                                                   ...           ...
# 231693  POLYGON ((-122.50254 47.40671, -122.50292 47.4...      23989721
# 231694  POLYGON ((-122.9147 47.22345, -122.91356 47.22...      23989715
# 231695  MULTIPOLYGON (((-122.63292 48.27784, -122.6330...      23989745
# 231696  MULTIPOLYGON (((-120.9911 48.70464, -120.99099...      24255303
# 231697  POLYGON ((-118.31368 47.88556, -118.31407 47.8...      23021612
#
# [231698 rows x 6 columns]

# %%
if spatial_gpd.crs == subcs.crs: 
    df = pd.concat([spatial_gpd, subcs.set_index('FEATUREID')['catchment_ID']], join = 'outer', axis = 1).reindex(spatial_gpd.index)
else: print('Error: conflicting CRS')

# %%
#df[:50].explore()

# %%
df_cols = df.columns.to_list()
new_cols = df_cols[:2] + ['catchment_ID'] + df_cols[3:-1] + ['geometry']
#new_cols

# %%
layer1 = df[new_cols]
layer1
# Out:
#                   huc10    FCODE  catchment_ID  cov.length_km  \
# COMID
# 22877591   1.701010e+09  55800.0      22877591          0.247
# 22877593   1.701010e+09  55800.0      22877593          0.055
# 22877595   1.701010e+09  46006.0      22877595          1.999
# 22877597   1.701010e+09  46006.0      22877597          0.947
# 22877599   1.701010e+09  46006.0      22877599          1.194
# ...                 ...      ...           ...            ...
# 947120094  1.712001e+09  46006.0     947120094          0.364
# 947120095  1.712001e+09  46006.0     947120095          0.418
# 947120098  1.712001e+09  46006.0     947120098          1.218
# 947120100  1.712001e+09  46003.0     947120100          2.893
# 947120101  1.712001e+09  46003.0     947120101          0.445
#
#            cov.stream_order  cov.path_length  cov.tot.da.sqkm  \
# COMID
# 22877591                6.0         1290.195       28030.5369
# 22877593                3.0         1290.442          58.4136
# 22877595                3.0         1290.497          58.3101
# 22877597                3.0         1292.496          54.7596
# 22877599                3.0         1293.443          48.1401
# ...                     ...              ...              ...
# 947120094               2.0           40.358          11.2266
# 947120095               2.0           39.940          11.3337
# 947120098               2.0           40.722          10.9971
# 947120100               3.0           39.940          44.0622
# 947120101               3.0           39.495          55.6632
#
#            cov.elev_max_smo  cov.elev_min_smo  cov.slope  ...  cov.canopy_rca  \
# COMID                                                     ...
# 22877591            56102.0           55932.0   0.006883  ...       89.000000
# 22877593            56129.0           56102.0   0.004909  ...       90.000000
# 22877595            73226.0           56129.0   0.085528  ...       90.500000
# 22877597            76725.0           73226.0   0.036948  ...       90.500000
# 22877599            81497.0           76725.0   0.039966  ...       90.333333
# ...                     ...               ...        ...  ...             ...
# 947120094          139672.0          139048.0   0.017143  ...       81.750000
# 947120095          139048.0          138629.0   0.010024  ...       80.500000
# 947120098          145858.0          139672.0   0.050788  ...       82.333333
# 947120100          140135.0          138629.0   0.005206  ...       81.000000
# 947120101          138629.0          138331.0   0.006697  ...       81.500000
#
#            cov.canopy_line  cov.area_sqkm  cov.canopy_ws  cov.dam_name  \
# COMID
# 22877591              90.0         1.9161      88.592748         Libby
# 22877593              90.0         0.4284      90.227047           NaN
# 22877595              90.0         1.0629      90.227450           NaN
# 22877597              90.0         2.2950      90.209778           NaN
# 22877599              90.0         1.2087      90.149263           NaN
# ...                    ...            ...            ...           ...
# 947120094             80.5         9.3834      82.665564           NaN
# 947120095             80.0        16.4007      82.645100           NaN
# 947120098             82.0         0.4815      82.684671           NaN
# 947120100             78.0         0.2196      80.865589           NaN
# 947120101             80.0         1.4031      81.230965           NaN
#
#            cov.proportion_dam_influenced  cov.distance_below_dam  \
# COMID
# 22877591                        0.831332                  71.294
# 22877593                             NaN                     NaN
# 22877595                             NaN                     NaN
# 22877597                             NaN                     NaN
# 22877599                             NaN                     NaN
# ...                                  ...                     ...
# 947120094                            NaN                     NaN
# 947120095                            NaN                     NaN
# 947120098                            NaN                     NaN
# 947120100                            NaN                     NaN
# 947120101                            NaN                     NaN
#
#            cov.dam_hgt_m  cov.dam_main_use  \
# COMID
# 22877591           129.0  Hydroelectricity
# 22877593             NaN               NaN
# 22877595             NaN               NaN
# 22877597             NaN               NaN
# 22877599             NaN               NaN
# ...                  ...               ...
# 947120094            NaN               NaN
# 947120095            NaN               NaN
# 947120098            NaN               NaN
# 947120100            NaN               NaN
# 947120101            NaN               NaN
#
#                                                     geometry
# COMID
# 22877591   LINESTRING Z (-115.97665 48.55862 0, -115.9780...
# 22877593   LINESTRING Z (-115.97724 48.55831 0, -115.9766...
# 22877595   LINESTRING Z (-116.00101 48.55763 0, -116.0006...
# 22877597   LINESTRING Z (-116.01247 48.55595 0, -116.0086...
# 22877599   LINESTRING Z (-116.02837 48.55589 0, -116.0243...
# ...                                                      ...
# 947120094  LINESTRING Z (-120.32129 42.38282 0, -120.3207...
# 947120095  LINESTRING Z (-120.31769 42.38113 0, -120.3175...
# 947120098  LINESTRING Z (-120.33013 42.3911 0, -120.32983...
# 947120100  LINESTRING Z (-120.30641 42.35695 0, -120.3063...
# 947120101  LINESTRING Z (-120.31349 42.3795 0, -120.31348...
#
# [227060 rows x 80 columns]

# %%
layer1.catchment_ID.isnull().unique()
# Out:
# array([False])

# %% [markdown]
# ## Layer 2: Subcatchment geometry table (aka "wings")

# %%
#subcs[:50].explore()

# %%
df2 = comids_all.copy()

# %%
layer2 = subcs.loc[comids_all.index][['FEATUREID', 'geometry']]
layer2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 layer2 = subcs.loc[comids_all.index][['FEATUREID', 'geometry']]
#       2 layer2
#
# File /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([   -81754,    -81753,    -81752,    -81751,    -81750,    -81749,\n          -81748,    -81747,    -81746,    -81745,\n       ...\n       947120087, 947120088, 947120089, 947120090, 947120091, 947120094,\n       947120095, 947120098, 947120100, 947120101],\n      dtype='int64', name='COMID', length=228673)] are in the [index]"

# %%
len(spatial_covs.columns)
# Out:
# 76

# %%
dbfwbd_files = glob.glob(r'../DATA/NHDPlusPN/NHDPlus17/WBDSnapshot/*/*.dbf') 
dbfwbd_files
# Out:
# ['../DATA/NHDPlusPN/NHDPlus17/WBDSnapshot/WBD/WBD_Subwatershed.dbf']

# %%
wbds = gpd.read_file(dbfwbd_files[0])
wbds[:3]
# Out:
#    OBJECTID     HUC_8      HUC_10        HUC_12         ACRES  NCONTRB_A  \
# 0     29788  17010206  1701020601  170102060103  31609.155982        0.0
# 1     29792  17010106  1701010601  170101060101  26139.003487        0.0
# 2     29794  17010101  1701010104  170101010404  17616.666849        0.0
#
#   HU_10_GNIS HU_12_GNIS                                 HU_10_NAME HU_10_MOD  \
# 0       None       None  North Fork Flathead River-Kishenehn Creek        NM
# 1       None       None                               Wigwam River        NM
# 2       None       None                  Young Creek-Pinkham Creek        NM
#
#    ...                                 HU_12_NAME HU_12_MOD HU_12_TYPE  \
# 0  ...  North Fork Flathead River-Kishenehn Creek        NM          S
# 1  ...                               Wigwam River        NM          S
# 2  ...                             Phillips Creek        NM          S
#
#   META_ID  STATES                                GlobalID SHAPE_Leng  \
# 0    MT08  MT,CAN  {33FBF763-C7B5-4239-AC93-30FCDAF6560C}   1.119923
# 1    MT07  MT,CAN  {FE944240-98C7-4BDC-BC4E-BC95EA8A69F3}   0.706215
# 2    MT01      MT  {2E15B098-D388-4F7B-BE46-DD86DBDAA4E7}   0.879199
#
#   SHAPE_Area  GAZ_ID                                           geometry
# 0   0.015712  -70260  POLYGON ((-114.22732 48.99958, -114.22856 48.9...
# 1   0.012991  -70261  POLYGON ((-114.72947 49.00001, -114.72966 48.9...
# 2   0.008756  -70262  POLYGON ((-114.91357 49.00007, -114.91414 48.9...
#
# [3 rows x 22 columns]

# %%
wbds.columns
# Out:
# Index(['OBJECTID', 'HUC_8', 'HUC_10', 'HUC_12', 'ACRES', 'NCONTRB_A',
#        'HU_10_GNIS', 'HU_12_GNIS', 'HU_10_NAME', 'HU_10_MOD', 'HU_10_TYPE',
#        'HU_12_DS', 'HU_12_NAME', 'HU_12_MOD', 'HU_12_TYPE', 'META_ID',
#        'STATES', 'GlobalID', 'SHAPE_Leng', 'SHAPE_Area', 'GAZ_ID', 'geometry'],
#       dtype='object')

# %%
wbds['HUC_12'].value_counts()
# Out:
# HUC_12
# 171003120302    335
# 171002010105    121
# 171003060401    115
# 171003060106    108
# 171003040308     84
#                ...
# 170703030904      1
# 170501161104      1
# 170703040801      1
# 171200020204      1
# 170200010203      1
# Name: count, Length: 8240, dtype: int64

# %%
df
# Out:
#                   huc10    FCODE  \
# COMID
# 22877591   1.701010e+09  55800.0
# 22877593   1.701010e+09  55800.0
# 22877595   1.701010e+09  46006.0
# 22877597   1.701010e+09  46006.0
# 22877599   1.701010e+09  46006.0
# ...                 ...      ...
# 947120094  1.712001e+09  46006.0
# 947120095  1.712001e+09  46006.0
# 947120098  1.712001e+09  46006.0
# 947120100  1.712001e+09  46003.0
# 947120101  1.712001e+09  46003.0
#
#                                                     geometry  cov.length_km  \
# COMID
# 22877591   LINESTRING Z (-115.97665 48.55862 0, -115.9780...          0.247
# 22877593   LINESTRING Z (-115.97724 48.55831 0, -115.9766...          0.055
# 22877595   LINESTRING Z (-116.00101 48.55763 0, -116.0006...          1.999
# 22877597   LINESTRING Z (-116.01247 48.55595 0, -116.0086...          0.947
# 22877599   LINESTRING Z (-116.02837 48.55589 0, -116.0243...          1.194
# ...                                                      ...            ...
# 947120094  LINESTRING Z (-120.32129 42.38282 0, -120.3207...          0.364
# 947120095  LINESTRING Z (-120.31769 42.38113 0, -120.3175...          0.418
# 947120098  LINESTRING Z (-120.33013 42.3911 0, -120.32983...          1.218
# 947120100  LINESTRING Z (-120.30641 42.35695 0, -120.3063...          2.893
# 947120101  LINESTRING Z (-120.31349 42.3795 0, -120.31348...          0.445
#
#            cov.stream_order  cov.path_length  cov.tot.da.sqkm  \
# COMID
# 22877591                6.0         1290.195       28030.5369
# 22877593                3.0         1290.442          58.4136
# 22877595                3.0         1290.497          58.3101
# 22877597                3.0         1292.496          54.7596
# 22877599                3.0         1293.443          48.1401
# ...                     ...              ...              ...
# 947120094               2.0           40.358          11.2266
# 947120095               2.0           39.940          11.3337
# 947120098               2.0           40.722          10.9971
# 947120100               3.0           39.940          44.0622
# 947120101               3.0           39.495          55.6632
#
#            cov.elev_max_smo  cov.elev_min_smo  cov.slope  ...  cov.canopy_rca  \
# COMID                                                     ...
# 22877591            56102.0           55932.0   0.006883  ...       89.000000
# 22877593            56129.0           56102.0   0.004909  ...       90.000000
# 22877595            73226.0           56129.0   0.085528  ...       90.500000
# 22877597            76725.0           73226.0   0.036948  ...       90.500000
# 22877599            81497.0           76725.0   0.039966  ...       90.333333
# ...                     ...               ...        ...  ...             ...
# 947120094          139672.0          139048.0   0.017143  ...       81.750000
# 947120095          139048.0          138629.0   0.010024  ...       80.500000
# 947120098          145858.0          139672.0   0.050788  ...       82.333333
# 947120100          140135.0          138629.0   0.005206  ...       81.000000
# 947120101          138629.0          138331.0   0.006697  ...       81.500000
#
#            cov.canopy_line  cov.area_sqkm  cov.canopy_ws  cov.dam_name  \
# COMID
# 22877591              90.0         1.9161      88.592748         Libby
# 22877593              90.0         0.4284      90.227047           NaN
# 22877595              90.0         1.0629      90.227450           NaN
# 22877597              90.0         2.2950      90.209778           NaN
# 22877599              90.0         1.2087      90.149263           NaN
# ...                    ...            ...            ...           ...
# 947120094             80.5         9.3834      82.665564           NaN
# 947120095             80.0        16.4007      82.645100           NaN
# 947120098             82.0         0.4815      82.684671           NaN
# 947120100             78.0         0.2196      80.865589           NaN
# 947120101             80.0         1.4031      81.230965           NaN
#
#            cov.proportion_dam_influenced  cov.distance_below_dam  \
# COMID
# 22877591                        0.831332                  71.294
# 22877593                             NaN                     NaN
# 22877595                             NaN                     NaN
# 22877597                             NaN                     NaN
# 22877599                             NaN                     NaN
# ...                                  ...                     ...
# 947120094                            NaN                     NaN
# 947120095                            NaN                     NaN
# 947120098                            NaN                     NaN
# 947120100                            NaN                     NaN
# 947120101                            NaN                     NaN
#
#            cov.dam_hgt_m  cov.dam_main_use  catchment_ID
# COMID
# 22877591           129.0  Hydroelectricity      22877591
# 22877593             NaN               NaN      22877593
# 22877595             NaN               NaN      22877595
# 22877597             NaN               NaN      22877597
# 22877599             NaN               NaN      22877599
# ...                  ...               ...           ...
# 947120094            NaN               NaN     947120094
# 947120095            NaN               NaN     947120095
# 947120098            NaN               NaN     947120098
# 947120100            NaN               NaN     947120100
# 947120101            NaN               NaN     947120101
#
# [227060 rows x 80 columns]

# %%
for h10 in [df.huc10.unique()[0]]:
    print(h10)
# Out:
# 1701010117.0

# %%
    cur_comids = df.loc[df.huc10 == h10]
    cur_comids
# Out:
#                  huc10    FCODE  \
# COMID
# 22877591  1.701010e+09  55800.0
# 22877593  1.701010e+09  55800.0
# 22877595  1.701010e+09  46006.0
# 22877597  1.701010e+09  46006.0
# 22877599  1.701010e+09  46006.0
# ...                ...      ...
# 22882357  1.701010e+09  46003.0
# 22882359  1.701010e+09  46006.0
# 22882433  1.701010e+09  46006.0
# 22882435  1.701010e+09  46006.0
# 22882437  1.701010e+09  46006.0
#
#                                                    geometry  cov.length_km  \
# COMID
# 22877591  LINESTRING Z (-115.97665 48.55862 0, -115.9780...          0.247
# 22877593  LINESTRING Z (-115.97724 48.55831 0, -115.9766...          0.055
# 22877595  LINESTRING Z (-116.00101 48.55763 0, -116.0006...          1.999
# 22877597  LINESTRING Z (-116.01247 48.55595 0, -116.0086...          0.947
# 22877599  LINESTRING Z (-116.02837 48.55589 0, -116.0243...          1.194
# ...                                                     ...            ...
# 22882357  LINESTRING Z (-116.03921 48.58215 0, -116.0389...          1.237
# 22882359  LINESTRING Z (-116.02895 48.57358 0, -116.0286...          2.673
# 22882433  LINESTRING Z (-115.89488 48.45376 0, -115.8950...          0.266
# 22882435  LINESTRING Z (-115.89609 48.45207 0, -115.8949...          0.239
# 22882437  LINESTRING Z (-115.89746 48.44908 0, -115.8976...          0.290
#
#           cov.stream_order  cov.path_length  cov.tot.da.sqkm  \
# COMID
# 22877591               6.0         1290.195       28030.5369
# 22877593               3.0         1290.442          58.4136
# 22877595               3.0         1290.497          58.3101
# 22877597               3.0         1292.496          54.7596
# 22877599               3.0         1293.443          48.1401
# ...                    ...              ...              ...
# 22882357               1.0         1296.116           2.8719
# 22882359               1.0         1293.443           5.5350
# 22882433               4.0         1305.372         213.0471
# 22882435               4.0         1305.617         212.1471
# 22882437               4.0         1305.939         211.8807
#
#           cov.elev_max_smo  cov.elev_min_smo  cov.slope  ...  cov.canopy_rca  \
# COMID                                                    ...
# 22877591           56102.0           55932.0   0.006883  ...       89.000000
# 22877593           56129.0           56102.0   0.004909  ...       90.000000
# 22877595           73226.0           56129.0   0.085528  ...       90.500000
# 22877597           76725.0           73226.0   0.036948  ...       90.500000
# 22877599           81497.0           76725.0   0.039966  ...       90.333333
# ...                    ...               ...        ...  ...             ...
# 22882357           88984.0           83774.0   0.047886  ...       91.000000
# 22882359           83774.0           76725.0   0.026371  ...       90.333333
# 22882433           58746.0           58379.0   0.031638  ...       89.000000
# 22882435           59001.0           58746.0   0.028652  ...       87.500000
# 22882437           59573.0           59261.0   0.022286  ...       88.000000
#
#           cov.canopy_line  cov.area_sqkm  cov.canopy_ws  cov.dam_name  \
# COMID
# 22877591        90.000000         1.9161      88.592748         Libby
# 22877593        90.000000         0.4284      90.227047           NaN
# 22877595        90.000000         1.0629      90.227450           NaN
# 22877597        90.000000         2.2950      90.209778           NaN
# 22877599        90.000000         1.2087      90.149263           NaN
# ...                   ...            ...            ...           ...
# 22882357        91.000000         3.1842      91.000000           NaN
# 22882359        90.333333         2.1357      90.679241           NaN
# 22882433        87.000000         4.8285      89.702518           NaN
# 22882435        87.000000         6.7212      89.705498           NaN
# 22882437        88.000000         2.5920      89.706983           NaN
#
#           cov.proportion_dam_influenced  cov.distance_below_dam  \
# COMID
# 22877591                       0.831332                  71.294
# 22877593                            NaN                     NaN
# 22877595                            NaN                     NaN
# 22877597                            NaN                     NaN
# 22877599                            NaN                     NaN
# ...                                 ...                     ...
# 22882357                            NaN                     NaN
# 22882359                            NaN                     NaN
# 22882433                            NaN                     NaN
# 22882435                            NaN                     NaN
# 22882437                            NaN                     NaN
#
#           cov.dam_hgt_m  cov.dam_main_use  catchment_ID
# COMID
# 22877591          129.0  Hydroelectricity      22877591
# 22877593            NaN               NaN      22877593
# 22877595            NaN               NaN      22877595
# 22877597            NaN               NaN      22877597
# 22877599            NaN               NaN      22877599
# ...                 ...               ...           ...
# 22882357            NaN               NaN      22882357
# 22882359            NaN               NaN      22882359
# 22882433            NaN               NaN      22882433
# 22882435            NaN               NaN      22882435
# 22882437            NaN               NaN      22882437
#
# [210 rows x 80 columns]

# %%
len(wbds)
# Out:
# 9823

# %%
len(wbds.HUC_12.unique())
# Out:
# 8241

# %%
#duplicates = df[df.duplicated(subset=['A'], keep=False)]
duplicates = wbds[wbds.duplicated(subset = ['HUC_12'], keep = False)]
dups1 = duplicates.loc[duplicates.HUC_12 == duplicates.HUC_12.unique()[2]]
len(dups1)
# Out:
# 27

# %%
dups1.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c9139c4a9ce1721cd0e04d36f707731 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c9139c4a9ce1721cd0e04d36f707731&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c9139c4a9ce1721cd0e04d36f707731 = L.map(
#                 &quot;map_9c9139c4a9ce1721cd0e04d36f707731&quot;,
#                 {
#                     center: [42.00274842169787, -124.21175042048343],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9c9139c4a9ce1721cd0e04d36f707731);
#
#
#
#
#
#             var tile_layer_d9a3f4b1109a773df75e710441ce4c64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9a3f4b1109a773df75e710441ce4c64.addTo(map_9c9139c4a9ce1721cd0e04d36f707731);
#
#
#             map_9c9139c4a9ce1721cd0e04d36f707731.fitBounds(
#                 [[41.949358167010914, -124.26992676115376], [42.05613867638484, -124.1535740798131]],
#                 {}
#             );
#
#
#         function geo_json_785278f96952dddf5730eac68c2b1864_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_785278f96952dddf5730eac68c2b1864_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_785278f96952dddf5730eac68c2b1864_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_785278f96952dddf5730eac68c2b1864_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_785278f96952dddf5730eac68c2b1864_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_785278f96952dddf5730eac68c2b1864.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_785278f96952dddf5730eac68c2b1864_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_785278f96952dddf5730eac68c2b1864 = L.geoJson(null, {
#                 onEachFeature: geo_json_785278f96952dddf5730eac68c2b1864_onEachFeature,
#
#                 style: geo_json_785278f96952dddf5730eac68c2b1864_styler,
#                 pointToLayer: geo_json_785278f96952dddf5730eac68c2b1864_pointToLayer,
#         });
#
#         function geo_json_785278f96952dddf5730eac68c2b1864_add (data) {
#             geo_json_785278f96952dddf5730eac68c2b1864
#                 .addData(data);
#         }
#             geo_json_785278f96952dddf5730eac68c2b1864_add({&quot;bbox&quot;: [-124.26992676115376, 41.949358167010914, -124.1535740798131, 42.05613867638484], &quot;features&quot;: [{&quot;bbox&quot;: [-124.21785623568162, 41.949895056348325, -124.21768710217133, 41.95003225642775], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-124.21779743490612, 41.950026789401406], [-124.21774603546176, 41.95003225642775], [-124.21770923555479, 41.950021389949924], [-124.21768710217133, 41.94999938858303], [-124.21768710260639, 41.949966457189184], [-124.21770910446962, 41.949933456795854], [-124.21776063652314, 41.94990059040229], [-124.21780470464299, 41.949895056348325], [-124.21784883587473, 41.94990598985367], [-124.21785623568162, 41.949938988274866], [-124.21784903423203, 41.94997745544799], [-124.2177

# %%
    for h12 in wbds.rows()[:3]:
        print(h12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/95/99dy_ns968195cnlvp5xhwqm0000gp/T/ipykernel_30113/733242004.py in ?()
# ----> 1 for h12 in wbds.rows()[:3]:
#       2     print(h12)
#
# /opt/miniconda3/envs/temp-data-env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'GeoDataFrame' object has no attribute 'rows'

# %%
        subcs[cur_comids.index].centroid.within(huc12) #should return a df of a several subcs in one huc12
        #Assign huc12 to df
        #frame_list.append(df)

# %%
covariate_metadata = pd.read_csv('../DATA/Stream_Temp/covariate_metadata.csv', nrows = 100)
covariate_metadata.tail(5)
# Out:
#          COVARIATE     UNITS    SYMBOL  \
# 95          lookup  unitless  not used
# 96        tim.date      date  not used
# 97        tim.year      year  not used
# 98  cov.canopy_rca   percent  not used
# 99   cov.canopy_ws   percent  not used
#
#                                           DESCRIPTION  \
# 95  concatination of reach identifier, year, and d...
# 96                                               date
# 97                                               year
# 98  proportional canopy cover in the reach contrib...
# 99  proportional canopy cover in the upstream wate...
#
#    DATA SOURCE (Retrospective) DATA SOURCE (GCM Scenarios)
# 95                         NaN                         NaN
# 96                         NaN                         NaN
# 97                         NaN                         NaN
# 98               need to check                         NaN
# 99               need to check                         NaN

# %%
covariate_metadata.COVARIATE.to_list()
# Out:
# ['COMID',
#  'cov.antec_air_temp',
#  'cov.air_temp_mean_ws',
#  'cov.SWE_ws',
#  'cov.daylength_hours',
#  'tim.doy',
#  'cov.std_mean_flow',
#  'cov.SWE_1Apr',
#  'cov.lat_v',
#  'cov.elev_mean_smo',
#  'cov.elev_diff',
#  'cov.area_km2_ws_log',
#  'cov.BFI_cat',
#  'cov.slope',
#  'cov.pct_ow_ws',
#  'cov.pct_wet_all_ws',
#  'cov.pct_ice_ws',
#  'cov.pct_for_all_cat_rip100m',
#  'cov.canopy_line',
#  'cov.pct_urb_all_ws',
#  'cov.pct_extru_vol_ws',
#  'cov.precip_cat',
#  'cov.air_temp_range_cat',
#  nan,
#  'cov.air_temp_max_cat',
#  'cov.air_temp_max_ws',
#  'cov.air_temp_mean_cat',
#  'cov.air_temp_min_cat',
#  'cov.air_temp_min_ws',
#  'cov.area_km2_ws',
#  'cov.area_sqkm',
#  'cov.BFI_ws',
#  'cov.canal_dens_cat',
#  'cov.canal_dens_ws',
#  'cov.dam_dens_cat',
#  'cov.dam_dens_ws',
#  'cov.dam_hgt_m',
#  'cov.dam_main_use',
#  'cov.dam_name',
#  'cov.dam_nrm_stor_cat',
#  'cov.dam_nrm_stor_ws',
#  'cov.distance_below_dam',
#  'cov.elev_max_smo',
#  'cov.elev_min_smo',
#  'cov.elev_cat',
#  'cov.elev_ws',
#  'cov.length_km',
#  'cov.om_cat',
#  'cov.om_ws',
#  'cov.path_length',
#  'cov.pct_bl_ws',
#  'cov.pct_conif_cat_rip100m',
#  'cov.pct_decid_cat_rip100m',
#  'cov.pct_extru_vol_cat',
#  'cov.pct_hb_wet_cat',
#  'cov.pct_hb_wet_cat_rip100m',
#  'cov.pct_hb_wet_ws',
#  'cov.pct_hb_wet_ws_rip100m',
#  'cov.pct_imp_cat',
#  'cov.pct_imp_cat_rip100m',
#  'cov.pct_imp_ws',
#  'cov.pct_imp_ws_rip100m',
#  'cov.pct_mx_fst_cat_rip100m',
#  'cov.pct_urb_hi_ws',
#  'cov.pct_urb_lo_ws',
#  'cov.pct_urb_md_ws',
#  'cov.pct_urb_op_ws',
#  'cov.pct_wd_wet_cat',
#  'cov.pct_wd_wet_cat_rip100m',
#  'cov.pct_wd_wet_ws',
#  'cov.pct_wd_wet_ws_rip100m',
#  'cov.perm_cat',
#  'cov.perm_ws',
#  'cov.precip_ws',
#  'cov.proportion_dam_influenced',
#  'cov.rck_dep_cat',
#  'cov.rck_dep_ws',
#  'cov.sinuosity',
#  'cov.stream_order',
#  'cov.tot.da.sqkm',
#  'cov.wt_dep_cat',
#  'cov.wt_dep_ws',
#  'SegID',
#  'cov.Flow',
#  'cov.Flow_log',
#  'cov.NWM_flow_log',
#  'cov.NWM_flow',
#  'cov.SWE',
#  'cov.SWE_last_doy',
#  'cov.SWE_mean_year',
#  'cov.air_temp',
#  'cov.air_temp_{n}d',
#  'cov.air_temp_ws',
#  'cov.daylength',
#  'Huc10',
#  'lookup',
#  'tim.date',
#  'tim.year',
#  'cov.canopy_rca',
#  'cov.canopy_ws']

# %%
set(spatial_covs.columns).difference(set(covariate_metadata.COVARIATE))
# Out:
# set()

# %%
temp_dir = '/Volumes/Elements/URycki/temp_data/'

# %%
temp_dir_retro = os.path.join(temp_dir, 'preds_retro/')
huc6_files = glob.glob(os.path.join(temp_dir_retro, 'st_pred_*.7z'))
huc6_files.sort()
huc6_files
# Out:
# ['/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170101.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170102.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170103.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170200.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170300.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170401.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170402.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170501.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170502.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170601.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170602.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170603.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170701.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170702.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170703.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170800.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170900.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_171001.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_171002.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_171003.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_171100.7z',
#  '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_171200.7z']

# %%
# List of HUC10s from RSX RME_scrape (assuming this is the comprehensive list?)
rsx_hucs_df = pd.read_csv('../../Repos/DATA/Region17_HUC10s.csv', skiprows = [0], names = ['huc10'])
rsx_hucs = rsx_hucs_df.huc10.to_list()
print(len(rsx_hucs))
rsx_hucs[:5]
# Out:
# 1526
# [1710010301, 1710030501, 1702001003, 1710010501, 1702000806]

# %% [markdown]
# ## Build retrospective projects

# %%
comid_by_huc = {}

# %% [markdown]
# ### Zipped database
# 1. daily stream temperature retrospective
# 2. daily covariates retrospective

# %%
def extract_7zs(archive):
    with py7zr.SevenZipFile(archive, mode='r') as z:
        z.extractall(path = os.path.join(temp_dir_retro, 'tmp'))
    return None

# %%
file = huc6_files[4]
file
# Out:
# '/Volumes/Elements/URycki/temp_data/preds_retro/st_pred_170300.7z'

# %%
extract_7zs(file)

# %%
import sqlite3

# %%
huc_files = glob.glob(os.path.join(temp_dir_retro, 'tmp', '*.csv'))

# %%
cur_file = huc_files[0]
cur_file
# Out:
# '/Volumes/Elements/URycki/temp_data/preds_retro/tmp/st_pred_1703000101.csv'

# %%
cur_huc = cur_file[-14:-4]
cur_huc
# Out:
# '1703000101'

# %%
df_raw = pd.read_csv(cur_file, parse_dates = ['tim.date'], engine = 'python', on_bad_lines = 'warn')
df = df_raw.sort_values(by = ['COMID', 'tim.date'])

# %%
df[:5]
# Out:
#                lookup     COMID   tim.date  cov.antec_air_temp  \
# 0     24125807_1990_1  24125807 1990-01-02                 NaN
# 337   24125807_1990_2  24125807 1990-01-03                 NaN
# 674   24125807_1990_3  24125807 1990-01-04                 NaN
# 1011  24125807_1990_4  24125807 1990-01-05                 NaN
# 1348  24125807_1990_5  24125807 1990-01-06                 NaN
#
#       cov.std_mean_flow  prd.stream_temp
# 0              1.054899              NaN
# 337            1.043976              NaN
# 674            1.032348              NaN
# 1011           1.020583              NaN
# 1348           1.009277              NaN

# %%
df.tail()
# Out:
#                     lookup     COMID   tim.date  cov.antec_air_temp  \
# 3937507  25006827_2021_361  25006827 2021-12-28           -6.637190
# 3937844  25006827_2021_362  25006827 2021-12-29           -7.173562
# 3938181  25006827_2021_363  25006827 2021-12-30           -7.673876
# 3938518  25006827_2021_364  25006827 2021-12-31           -8.044447
# 3938855  25006827_2021_365  25006827 2022-01-01           -8.225133
#
#          cov.std_mean_flow  prd.stream_temp
# 3937507           0.821878              NaN
# 3937844           0.821878              NaN
# 3938181           0.821878              NaN
# 3938518           0.821878              NaN
# 3938855           0.821878              NaN

# %%
temp = df[['COMID', 'tim.date', 'prd.stream_temp']]
temp
# Out:
#             COMID   tim.date  prd.stream_temp
# 0        24125807 1990-01-02              NaN
# 337      24125807 1990-01-03              NaN
# 674      24125807 1990-01-04              NaN
# 1011     24125807 1990-01-05              NaN
# 1348     24125807 1990-01-06              NaN
# ...           ...        ...              ...
# 3937507  25006827 2021-12-28              NaN
# 3937844  25006827 2021-12-29              NaN
# 3938181  25006827 2021-12-30              NaN
# 3938518  25006827 2021-12-31              NaN
# 3938855  25006827 2022-01-01              NaN
#
# [3938856 rows x 3 columns]

# %%
comid_by_huc[cur_huc] = temp.COMID.unique().tolist()

# %%
cur_huc
# Out:
# '1703000101'

# %%
temp_dir
# Out:
# '/Volumes/Elements/URycki/temp_data/'

# %%
conn = sqlite3.connect(os.path.join(temp_dir, 'Outputs', 'retro', f'retrospective_daily_{cur_huc}.db'))

# Write the DataFrame to a table in the database
temp.to_sql("stream_temperature", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

# %%
#test
gpd.read_file(os.path.join(temp_dir, 'Outputs', 'retro', f'retrospective_daily_{cur_huc}.db'))
# Out:
#             COMID   tim.date  prd.stream_temp
# 0        24125807 1990-01-02              NaN
# 1        24125807 1990-01-03              NaN
# 2        24125807 1990-01-04              NaN
# 3        24125807 1990-01-05              NaN
# 4        24125807 1990-01-06              NaN
# ...           ...        ...              ...
# 3938851  25006827 2021-12-28              NaN
# 3938852  25006827 2021-12-29              NaN
# 3938853  25006827 2021-12-30              NaN
# 3938854  25006827 2021-12-31              NaN
# 3938855  25006827 2022-01-01              NaN
#
# [3938856 rows x 3 columns]

# %%
table2 = df

# %%
conn = sqlite3.connect(os.path.join(temp_dir, 'Outputs', 'retro', f'retrospective_daily_{cur_huc}.db'))

# Write the DataFrame to a table in the database
table2.to_sql("test_table", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

# %%
gpd.read_file(os.path.join(temp_dir, 'Outputs', 'retro', f'retrospective_daily_{cur_huc}.db'), layer = 'test_table')
# Out:
#                     lookup     COMID   tim.date  cov.antec_air_temp  \
# 0          24125807_1990_1  24125807 1990-01-02                 NaN
# 1          24125807_1990_2  24125807 1990-01-03                 NaN
# 2          24125807_1990_3  24125807 1990-01-04                 NaN
# 3          24125807_1990_4  24125807 1990-01-05                 NaN
# 4          24125807_1990_5  24125807 1990-01-06                 NaN
# ...                    ...       ...        ...                 ...
# 3938851  25006827_2021_361  25006827 2021-12-28           -6.637190
# 3938852  25006827_2021_362  25006827 2021-12-29           -7.173562
# 3938853  25006827_2021_363  25006827 2021-12-30           -7.673876
# 3938854  25006827_2021_364  25006827 2021-12-31           -8.044447
# 3938855  25006827_2021_365  25006827 2022-01-01           -8.225133
#
#          cov.std_mean_flow  prd.stream_temp
# 0                 1.054899              NaN
# 1                 1.043976              NaN
# 2                 1.032348              NaN
# 3                 1.020583              NaN
# 4                 1.009277              NaN
# ...                    ...              ...
# 3938851           0.821878              NaN
# 3938852           0.821878              NaN
# 3938853           0.821878              NaN
# 3938854           0.821878              NaN
# 3938855           0.821878              NaN
#
# [3938856 rows x 6 columns]

# %%
gpd.list_layers(os.path.join(temp_dir, 'Outputs', 'retro', f'retrospective_daily_{cur_huc}.db'))
# Out:
#                  name geometry_type
# 0  stream_temperature          None
# 1          test_table          None

# %%
Next: see if it saves space to use one db file instead of two.

# %%
temp[~temp.isnull().any(axis =1)]
# Out:
#            tim.date  prd.stream_temp
# COMID
# 24127141 1990-01-02         0.815321
# 25006797 1990-01-02         1.030870
# 24127141 1990-01-03         1.113983
# 25006797 1990-01-03         1.814799
# 24127141 1990-01-04         3.167158
# ...             ...              ...
# 25006819 2021-10-01         1.977966
# 25006821 2021-10-01         0.914263
# 25006823 2021-10-01         0.225544
# 25006825 2021-10-01         1.238325
# 25006827 2021-10-01         0.098375
#
# [3459800 rows x 2 columns]

# %%
df[~df.isnull()]
# Out:
#            tim.date  prd.stream_temp
# COMID
# 24125807 1990-01-02              NaN
# 24125809 1990-01-02              NaN
# 24125811 1990-01-02              NaN
# 24125813 1990-01-02              NaN
# 24125815 1990-01-02              NaN
# ...             ...              ...
# 25006819 2022-01-01              NaN
# 25006821 2022-01-01              NaN
# 25006823 2022-01-01              NaN
# 25006825 2022-01-01              NaN
# 25006827 2022-01-01              NaN
#
# [3938856 rows x 2 columns]

# %%
df[~df.isna().all(axis=1)]
# Out:
#                     lookup     COMID   tim.date  cov.antec_air_temp  \
# 0          24125807_1990_1  24125807 1990-01-02                 NaN
# 1          24125809_1990_1  24125809 1990-01-02                 NaN
# 2          24125811_1990_1  24125811 1990-01-02                 NaN
# 3          24125813_1990_1  24125813 1990-01-02                 NaN
# 4          24125815_1990_1  24125815 1990-01-02                 NaN
# ...                    ...       ...        ...                 ...
# 3938851  25006819_2021_365  25006819 2022-01-01           -6.346550
# 3938852  25006821_2021_365  25006821 2022-01-01           -6.838933
# 3938853  25006823_2021_365  25006823 2022-01-01           -6.096833
# 3938854  25006825_2021_365  25006825 2022-01-01           -8.553583
# 3938855  25006827_2021_365  25006827 2022-01-01           -8.225133
#
#          cov.std_mean_flow  prd.stream_temp
# 0                 1.054899              NaN
# 1                 1.056818              NaN
# 2                 1.057383              NaN
# 3                 1.069315              NaN
# 4                 1.078398              NaN
# ...                    ...              ...
# 3938851           0.861358              NaN
# 3938852           0.831395              NaN
# 3938853           1.208477              NaN
# 3938854           0.499316              NaN
# 3938855           0.821878              NaN
#
# [3938856 rows x 6 columns]

# %%
3938856 rows × 6 columns
# Out:
#   Cell In[137], line 1
#     3938856 rows × 6 columns
#                  ^
# SyntaxError: invalid character '×' (U+00D7)

# %%
df
# Out:
#                     lookup     COMID   tim.date  cov.antec_air_temp  \
# 0          24125807_1990_1  24125807 1990-01-02                 NaN
# 1          24125809_1990_1  24125809 1990-01-02                 NaN
# 2          24125811_1990_1  24125811 1990-01-02                 NaN
# 3          24125813_1990_1  24125813 1990-01-02                 NaN
# 4          24125815_1990_1  24125815 1990-01-02                 NaN
# ...                    ...       ...        ...                 ...
# 3938851  25006819_2021_365  25006819 2022-01-01           -6.346550
# 3938852  25006821_2021_365  25006821 2022-01-01           -6.838933
# 3938853  25006823_2021_365  25006823 2022-01-01           -6.096833
# 3938854  25006825_2021_365  25006825 2022-01-01           -8.553583
# 3938855  25006827_2021_365  25006827 2022-01-01           -8.225133
#
#          cov.std_mean_flow  prd.stream_temp
# 0                 1.054899              NaN
# 1                 1.056818              NaN
# 2                 1.057383              NaN
# 3                 1.069315              NaN
# 4                 1.078398              NaN
# ...                    ...              ...
# 3938851           0.861358              NaN
# 3938852           0.831395              NaN
# 3938853           1.208477              NaN
# 3938854           0.499316              NaN
# 3938855           0.821878              NaN
#
# [3938856 rows x 6 columns]

# %%
huc_comids = {}

# %% [markdown]
# ### Layer1: ComID geometry table. Feature ID (ComID), attributes (Fcode, SegID, [spatial covariates retrospective])

# %% [markdown]
# ### Layer3: Anomaly temperature metrics (seasonal)

# %%
huc_comids = {}

# %%
cur_huc = avail_hucs[1]
cur_huc
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cur_huc = avail_hucs[1]
#       2 cur_huc
#
# IndexError: list index out of range

# %%
anoms = pd.read_csv(os.path.join(temp_dir_retro + 'seasonal_anomalies/', f'{cur_huc}_anoms.zip'), compression = 'zip')
anoms = anoms[~anoms.COMID.isnull()]
anoms
# Out:
#         COMID  season 2010s 1990s 2000s
# 1  22878865.0    fall   NaN   NaN   NaN
# 2  22878865.0  spring   NaN   NaN   NaN
# 3  22878865.0  summer   NaN   NaN   NaN
# 4  22878865.0  winter   NaN   NaN   NaN

# %%
#df.columns = ['log(gdp)' if x=='gdp' else 'cap_mod' if x=='cap' else x for x in df.columns]
anoms.columns = [f'prd.stream_temp_{c}[C]' if c == '2010s' else f'prd.stream_temp_{c}[delta_C]' if c[0].isnumeric() else c for c in anoms.columns]
anoms
# Out:
#         COMID  season prd.stream_temp_2010s[C] prd.stream_temp_1990s[delta_C]  \
# 1  22878865.0    fall                      NaN                            NaN
# 2  22878865.0  spring                      NaN                            NaN
# 3  22878865.0  summer                      NaN                            NaN
# 4  22878865.0  winter                      NaN                            NaN
#
#   prd.stream_temp_2000s[delta_C]
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
cur_comids = anoms.COMID.unique().tolist()
cur_comids
# Out:
# [22878865.0]

# %%
huc_comids[cur_huc] = cur_comids
huc_comids
# Out:
# {'1701010106': [22878865.0]}

# %%
flowlines
# Out:
#            COMID      FDATE RESOLUTION  GNIS_ID               GNIS_NAME  \
# 0        9301535 1999-10-08     Medium     None                    None
# 1       22968128 2001-03-02     Medium     None                    None
# 2       22968138 2001-03-02     Medium     None                    None
# 3       23135995 2001-02-07     Medium     None                    None
# 4       23135997 2001-02-07     Medium     None                    None
# ...          ...        ...        ...      ...                     ...
# 272335  24545039 2005-08-27     Medium     None                    None
# 272336  24545041 2005-08-27     Medium     None                    None
# 272337  23706720 2001-02-28     Medium     None                    None
# 272338  23931942 2001-03-14     Medium  1127294  South Fork Keene Creek
# 272339  24279568 2001-04-17     Medium  1503026          Anderson Creek
#
#         LENGTHKM       REACHCODE         FLOWDIR  WBAREACOMI        FTYPE  \
# 0          0.999  09040002011583   Uninitialized           0  StreamRiver
# 1          0.134  10030104009812   Uninitialized           0  StreamRiver
# 2          0.217  10030104009813   Uninitialized           0  StreamRiver
# 3          0.916  16010102003533   Uninitialized           0  StreamRiver
# 4          1.865  16010102003534   Uninitialized           0  StreamRiver
# ...          ...             ...             ...         ...          ...
# 272335     2.847  17120009001542   Uninitialized           0  StreamRiver
# 272336     2.005  17120009001543   Uninitialized           0  StreamRiver
# 272337     4.217  18010201002017   Uninitialized           0  StreamRiver
# 272338     0.029  18010206012384   Uninitialized           0  StreamRiver
# 272339     3.453  17110011000269  With Digitized           0  StreamRiver
#
#         FCODE  SHAPE_LENG ENABLED  GNIS_NBR  \
# 0       46006    0.011661    True         0
# 1       46003    0.001671    True         0
# 2       46003    0.002145    True         0
# 3       46003    0.010671    True         0
# 4       46003    0.019193    True         0
# ...       ...         ...     ...       ...
# 272335  46003    0.029718    True         0
# 272336  46003    0.020023    True         0
# 272337  46003    0.043621    True         0
# 272338  46006    0.000284    True         0
# 272339  46003    0.021796    True         0
#
#                                                  geometry
# 0       LINESTRING Z (-114.05855 48.99999 0, -114.0583...
# 1       LINESTRING Z (-113.00089 47.46274 0, -113.0020...
# 2       LINESTRING Z (-113.0013 47.45837 0, -113.00137...
# 3       LINESTRING Z (-111.06214 42.50841 0, -111.0619...
# 4       LINESTRING Z (-111.04516 42.51372 0, -111.0447...
# ...                                                   ...
# 272335  LINESTRING Z (-118.12671 42.98327 0, -118.1260...
# 272336  LINESTRING Z (-118.1111 42.99525 0, -118.11175...
# 272337  LINESTRING Z (-121.60348 43.32724 0, -121.6034...
# 272338  LINESTRING Z (-122.47671 42.08355 0, -122.4765...
# 272339  LINESTRING Z (-122.06432 47.82127 0, -122.0647...
#
# [272340 rows x 15 columns]

# %%
flowlines[flowlines.COMID.isin(cur_comids)][['FCODE',
# Out:
#         COMID      FDATE RESOLUTION GNIS_ID    GNIS_NAME  LENGTHKM  \
# 687  22878865 2001-02-28     Medium  793620  Young Creek     2.324
#
#           REACHCODE         FLOWDIR  WBAREACOMI           FTYPE  FCODE  \
# 687  17010101000584  With Digitized    22886855  ArtificialPath  55800
#
#      SHAPE_LENG ENABLED  GNIS_NBR  \
# 687    0.028278    True         0
#
#                                               geometry
# 687  LINESTRING Z (-115.18951 48.9611 0, -115.18529...

# %%
hucs = [f[-13:-3] for f in temp_files_gcms]

# %%
# Select columns with 'float64' dtype  
float64_cols = list(huc_anoms.select_dtypes(include='float64'))

# The same code again calling the columns
huc_anoms[float64_cols] = huc_anoms[float64_cols].astype('float32')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Select columns with 'float64' dtype
# ----> 2 float64_cols = list(huc_anoms.select_dtypes(include='float64'))
#       4 # The same code again calling the columns
#       5 huc_anoms[float64_cols] = huc_anoms[float64_cols].astype('float32')
#
# NameError: name 'huc_anoms' is not defined

# %% [markdown]
# ### Covariate anomalies

# %%
temp_dir_retro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 temp_dir_retro
#
# NameError: name 'temp_dir_retro' is not defined

# %%
cov_retro_dir = os.path.join(temp_dir, 'cov_retro')
cov_retro_dir
# Out:
# '/Volumes/Elements/URycki/temp_data/cov_retro'

# %%
#retro covariates
hucs = [f[-14:-4] for f in glob.glob(cov_retro_dir + '/*')]
hucs.sort()

# %%
temp_files_retro = glob.glob(temp_dir_retro + 'seasonal_anomalies/' + '*.zip')
print(len(temp_files_retro))
print(temp_files_retro[:3])
temp_files_retro.sort()
# Out:
# 1536
# ['/Volumes/Elements/URycki/temp_data/preds_retro/seasonal_anomalies/1701010107_anoms.zip', '/Volumes/Elements/URycki/temp_data/preds_retro/seasonal_anomalies/1701010108_anoms.zip', '/Volumes/Elements/URycki/temp_data/preds_retro/seasonal_anomalies/1701010106_anoms.zip']
